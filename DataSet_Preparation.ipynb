# %%
import pandas as pd
import numpy as np

# %%
vac_data = pd.read_csv("vaccinations.csv")

# %%
len(vac_data)
# Out:
# 93395

# %%
vac_data.shape
# Out:
# (93395, 16)

# %%
vac_data.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
vac_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93395 entries, 0 to 93394
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             93395 non-null  object
#  1   iso_code                             93395 non-null  object
#  2   date                                 93395 non-null  object
#  3   total_vaccinations                   49650 non-null  float64
#  4   people_vaccinated                    47290 non-null  float64
#  5   people_fully_vaccinated              44651 non-null  float64
#  6   total_boosters                       21080 non-null  float64
#  7   daily_vaccinations_raw               41280 non-null  float64
#  8   daily_vaccinations                   93094 non-null  float64
#  9   total_vaccinations_per_hundred       49650 non-null  float64
#  10  people_vaccinated_per_hundred        47290 non-null  float64
# ...

# %%
print(vac_data.isna().sum())
print(30 * '-')
print('Total missing values are:', vac_data.isna().sum().sum())
print(30 * '-')
# Out:
# location                                   0
# iso_code                                   0
# date                                       0
# total_vaccinations                     43745
# people_vaccinated                      46105
# people_fully_vaccinated                48744
# total_boosters                         72315
# daily_vaccinations_raw                 52115
# daily_vaccinations                       301
# total_vaccinations_per_hundred         43745
# people_vaccinated_per_hundred          46105
# people_fully_vaccinated_per_hundred    48744
# total_boosters_per_hundred             72315
# daily_vaccinations_per_million           301
# daily_people_vaccinated                 1192
# daily_people_vaccinated_per_hundred     1192
# dtype: int64
# ------------------------------
# Total missing values are: 476919
# ------------------------------

# %%
vac_data.location
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 93390       Zimbabwe
# 93391       Zimbabwe
# 93392       Zimbabwe
# 93393       Zimbabwe
# 93394       Zimbabwe
# Name: location, Length: 93395, dtype: object

# %%
for col in vac_data:
    print(vac_data['location'].unique())
# Out:
# ['Afghanistan' 'Africa' 'Albania' 'Algeria' 'Andorra' 'Angola' 'Anguilla'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Asia' 'Australia'
#  'Austria' 'Azerbaijan' 'Bahamas' 'Bahrain' 'Bangladesh' 'Barbados'
#  'Belarus' 'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bonaire Sint Eustatius and Saba' 'Bosnia and Herzegovina' 'Botswana'
#  'Brazil' 'British Virgin Islands' 'Brunei' 'Bulgaria' 'Burkina Faso'
#  'Burundi' 'Cambodia' 'Cameroon' 'Canada' 'Cape Verde' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Chile' 'China' 'Colombia' 'Comoros'
#  'Congo' 'Cook Islands' 'Costa Rica' "Cote d'Ivoire" 'Croatia' 'Cuba'
#  'Curacao' 'Cyprus' 'Czechia' 'Democratic Republic of Congo' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt'
#  'El Salvador' 'England' 'Equatorial Guinea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Europe' 'European Union' 'Faeroe Islands' 'Falkland Islands'
# ...

# %%
#df1 = df[df['Age'] >= 37]
afg_vac_data = vac_data[vac_data['location'] == 'Afghanistan']
afg_vac_data
# Out:
#         location iso_code        date  total_vaccinations  people_vaccinated  \
# 0    Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1    Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2    Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3    Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4    Afghanistan      AFG  2021-02-26                 NaN                NaN
# ..           ...      ...         ...                 ...                ...
# 402  Afghanistan      AFG  2022-03-31                 NaN                NaN
# 403  Afghanistan      AFG  2022-04-01                 NaN                NaN
# 404  Afghanistan      AFG  2022-04-02                 NaN                NaN
# 405  Afghanistan      AFG  2022-04-03                 NaN                NaN
# 406  Afghanistan      AFG  2022-04-04           5872684.0          5188057.0
#
# ...

# %%
usa_vac_data = vac_data[vac_data['location'] == 'United States']
usa_vac_data
# Out:
#             location iso_code        date  total_vaccinations  \
# 88186  United States      USA  2020-12-13             31018.0
# 88187  United States      USA  2020-12-14             35600.0
# 88188  United States      USA  2020-12-15             85393.0
# 88189  United States      USA  2020-12-16            245348.0
# 88190  United States      USA  2020-12-17            518029.0
# ...              ...      ...         ...                 ...
# 88658  United States      USA  2022-03-30         561411861.0
# 88659  United States      USA  2022-03-31         561831270.0
# 88660  United States      USA  2022-04-01         562271679.0
# 88661  United States      USA  2022-04-02         562420626.0
# 88662  United States      USA  2022-04-03         562435301.0
#
#        people_vaccinated  people_fully_vaccinated  total_boosters  \
# 88186            25749.0                   6218.0             NaN
# 88187            30170.0                   6338.0             NaN
# ...

# %%
usa_vac_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477 entries, 88186 to 88662
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             477 non-null    object
#  1   iso_code                             477 non-null    object
#  2   date                                 477 non-null    object
#  3   total_vaccinations                   477 non-null    float64
#  4   people_vaccinated                    477 non-null    float64
#  5   people_fully_vaccinated              477 non-null    float64
#  6   total_boosters                       234 non-null    float64
#  7   daily_vaccinations_raw               476 non-null    float64
#  8   daily_vaccinations                   476 non-null    float64
#  9   total_vaccinations_per_hundred       477 non-null    float64
#  10  people_vaccinated_per_hundred        477 non-null    float64
# ...

# %%
usa_vac_data.drop(['iso_code', 'daily_vaccinations_raw'], axis=1)

# %%
infection_data = pd.read_csv("worldometer_data.csv")

# %%
infection_data
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
infection_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
usa_infection_data = infection_data[infection_data['Country/Region'] == 'USA']
usa_infection_data
# Out:
#   Country/Region      Continent   Population  TotalCases  NewCases  \
# 0            USA  North America  331198130.0     5032179       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
#
#    Tests/1M pop WHO Region
# 0      190640.0   Americas
